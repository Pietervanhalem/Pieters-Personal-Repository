# %%
import os
 
from sqlalchemy import Column, DateTime, String, Integer, ForeignKey, func, create_engine, Sequence
from sqlalchemy.orm import relationship, backref, sessionmaker
from sqlalchemy.ext.declarative import declarative_base

import pandas as pd
import requests

# %%
def get_user(i):
    users_list = []
    
    for j in range(i):
        user_data = requests.get('https://randomuser.me/api/').json()['results'][0]
        
        user = User()
        user.name = user_data['name']['first'] + ' '+ user_data['name']['last']
        user.email = user_data['email']
        user.country = user_data['location']['country']
        user.city = user_data['location']['city']
        
        comp = 'IT' if user.country in ['Netherlands', 'France', 'Germany'] else 'Estimating'
        company = session.query(Department).filter_by(name=comp).first()        
        company.user.append(user)
        
        UNI = 'TU Delft' if user.country in ['Canada', 'Australia', 'Netherlands'] else 'TU Twente'
        UNI = session.query(University).filter_by(name=UNI).first() 
        UNI.user.append(user)       
        
        users_list.append(user)
    return users_list

# %%
engine = create_engine('sqlite:///:memory:')

# %%
Base = declarative_base()

class University(Base):
    __tablename__ = 'universities'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email_address = Column(String)
    
    user = relationship("User", back_populates="universities")


class Department(Base):
    __tablename__ = 'departments'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email_address = Column(String)
    
    user = relationship("User", back_populates="departments")
    
class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, Sequence('user_id_seq'), primary_key=True)
    name = Column ('name', String(50), unique = True)
    email = Column ('email', String(50))
    city = Column ('city', String(50))
    country = Column ('country', String(50))
    department_name = Column(String(50), ForeignKey('departments.name'))
    university = Column(String(50), ForeignKey('universities.name'))

    departments = relationship("Department", order_by=Department.id, back_populates="user")
    universities = relationship("University", order_by=University.id, back_populates="user")

    


Session = sessionmaker(bind=engine)
Base.metadata.create_all(bind=engine)

session = Session()
session.commit()
session.close()

# %%
session = Session()

IT = Department()
IT.email_address = 'bla@bla.com'
IT.name = 'IT'

Estimating = Department()
Estimating.email_address = 'Estimating@bla.com'
Estimating.name = 'Estimating'

TU = University()
TU.email_address = 'TU_delft@bla.com'
TU.name = 'TU Delft'

TUT = University()
TUT.email_address = 'TU_Twente@bla.com'
TUT.name = 'TU Twente'

session.add_all([IT, Estimating, TU,TUT])
session.commit()

# %%
# %%time
U = get_user(100)
# Out:
# Wall time: 24.6 s

# %%
# %%time
session.add_all(U)
session.commit()
# Out:
# Wall time: 3 ms

# %%
pd.read_sql_table('users', engine, index_col='id')
# Out:
#                     name                            email  \
# id
# 1           Edward Gomez         edward.gomez@example.com
# 2             Arnd Jauch           arnd.jauch@example.com
# 3    Marcelina Stenersen  marcelina.stenersen@example.com
# 4     Frederick Reynolds   frederick.reynolds@example.com
# 5             سپهر کریمی          sphr.khrymy@example.com
# 6          Linn Nedrelid        linn.nedrelid@example.com
# 7             Cléa David           clea.david@example.com
# 8         Murat Dalkıran       murat.dalkiran@example.com
# 9       Milagros Gallego     milagros.gallego@example.com
# 10         Fernando Walz        fernando.walz@example.com
# 11         Ömür Aşıkoğlu        omur.asikoglu@example.com
# 12      Gloria Carpenter     gloria.carpenter@example.com
# 13            Mehdi Otte           mehdi.otte@example.com
# 14         Oliver Jensen        oliver.jensen@example.com
# 15       Ylja Otterspeer      ylja.otterspeer@example.com
# 16         سورنا رضاییان           swrn.rdyyn@example.com
# 17   Nelleke Van Beurden   nelleke.vanbeurden@example.com
# 18        Maddison Davis       maddison.davis@example.com
# 19          Frida Hansen         frida.hansen@example.com
# 20            Mark Miles           mark.miles@example.com
# 21           Antoine Chu          antoine.chu@example.com
# 22          Bessie Price         bessie.price@example.com
# 23         Keira Jackson        keira.jackson@example.com
# 24         Ömer Schrader        omer.schrader@example.com
# 25          Andre Kelley         andre.kelley@example.com
# 26            آراد پارسا              ard.prs@example.com
# 27        Vildan Samancı       vildan.samanci@example.com
# 28         August Martin        august.martin@example.com
# 29           Leah Tucker          leah.tucker@example.com
# 30        Jordan Kennedy       jordan.kennedy@example.com
# ..                   ...                              ...
# 71     Christina Fleming    christina.fleming@example.com
# 72           Meghan Hill          meghan.hill@example.com
# 73         Nathan Morris        nathan.morris@example.com
# 74      Jonas Kristensen     jonas.kristensen@example.com
# 75         Adem Alnıaçık        adem.alniacik@example.com
# 76            Janet Hale           janet.hale@example.com
# 77            Alex Mills           alex.mills@example.com
# 78         Morgan Leroux        morgan.leroux@example.com
# 79           Varg Sørlie          varg.sorlie@example.com
# 80           Quinn Lewis          quinn.lewis@example.com
# 81       Isabella Fortin      isabella.fortin@example.com
# 82          Ramon Harper         ramon.harper@example.com
# 83           Amber Smith          amber.smith@example.com
# 84          Avery Walker         avery.walker@example.com
# 85               Amy Fox              amy.fox@example.com
# 86          علیرضا نجاتی          aalyrd.njty@example.com
# 87      Roald Van Koppen      roald.vankoppen@example.com
# 88         Sofia Lemaire        sofia.lemaire@example.com
# 89      Patricia Frazier     patricia.frazier@example.com
# 90          Julie Madsen         julie.madsen@example.com
# 91            Logan Bell           logan.bell@example.com
# 92   Mestan Barbarosoğlu  mestan.barbarosoglu@example.com
# 93            Lloyd Lord           lloyd.lord@example.com
# 94           مهرسا احمدی            mhrs.hmdy@example.com
# 95         Grace Jackson        grace.jackson@example.com
# 96         Jasmin Menard        jasmin.menard@example.com
# 97          Jean Daniels         jean.daniels@example.com
# 98           Molly Allen          molly.allen@example.com
# 99           Jay Griffin          jay.griffin@example.com
# 100         Layla Wright         layla.wright@example.com
#
#                            city         country department_name university
# id
# 1                     Busselton       Australia      Estimating   TU Delft
# 2                        Greven         Germany              IT  TU Twente
# 3                       Svorkmo          Norway      Estimating  TU Twente
# 4                       Mildura       Australia      Estimating   TU Delft
# 5                        آبادان            Iran      Estimating  TU Twente
# 6                       Langset          Norway      Estimating  TU Twente
# 7                          Caen          France              IT  TU Twente
# 8                       Hakkâri          Turkey      Estimating  TU Twente
# 9    Las Palmas de Gran Canaria           Spain      Estimating  TU Twente
# 10                     Gladbeck         Germany              IT  TU Twente
# 11                        Niğde          Turkey      Estimating  TU Twente
# 12                    Daly City   United States      Estimating  TU Twente
# 13                    Heimsheim         Germany              IT  TU Twente
# 14                  Stokkemarke         Denmark      Estimating  TU Twente
# 15                  Hoogerheide     Netherlands              IT   TU Delft
# 16                     خرم‌آباد            Iran      Estimating  TU Twente
# 17                     Ulicoten     Netherlands              IT   TU Delft
# 18                   Sunderland  United Kingdom      Estimating  TU Twente
# 19                  København S         Denmark      Estimating  TU Twente
# 20                      Thurles         Ireland      Estimating  TU Twente
# 21                       Jasper          Canada      Estimating   TU Delft
# 22                       Albury       Australia      Estimating   TU Delft
# 23                      Porirua     New Zealand      Estimating  TU Twente
# 24                    Ebersberg         Germany              IT  TU Twente
# 25                  Rockhampton       Australia      Estimating   TU Delft
# 26                       سبزوار            Iran      Estimating  TU Twente
# 27                         Uşak          Turkey      Estimating  TU Twente
# 28                    Stansstad     Switzerland      Estimating  TU Twente
# 29                      Ballina         Ireland      Estimating  TU Twente
# 30                   Launceston       Australia      Estimating   TU Delft
# ..                          ...             ...             ...        ...
# 71                      Roscrea         Ireland      Estimating  TU Twente
# 72                  Sioux Falls   United States      Estimating  TU Twente
# 73                    Whangarei     New Zealand      Estimating  TU Twente
# 74                    Støvring          Denmark      Estimating  TU Twente
# 75                    Gaziantep          Turkey      Estimating  TU Twente
# 76                       Exeter  United Kingdom      Estimating  TU Twente
# 77                      Phoenix   United States      Estimating  TU Twente
# 78                Saint-Étienne          France              IT  TU Twente
# 79                        Maura          Norway      Estimating  TU Twente
# 80                   Lower Hutt     New Zealand      Estimating  TU Twente
# 81                      Belmont          Canada      Estimating   TU Delft
# 82                          Ely  United Kingdom      Estimating  TU Twente
# 83                     Blenheim     New Zealand      Estimating  TU Twente
# 84                     Tecumseh          Canada      Estimating   TU Delft
# 85                       Durham  United Kingdom      Estimating  TU Twente
# 86                       بجنورد            Iran      Estimating  TU Twente
# 87                 Egmondermeer     Netherlands              IT   TU Delft
# 88                      Mesocco     Switzerland      Estimating  TU Twente
# 89                       Tralee         Ireland      Estimating  TU Twente
# 90                       Hammel         Denmark      Estimating  TU Twente
# 91                  Westminster  United Kingdom      Estimating  TU Twente
# 92                      Kocaeli          Turkey      Estimating  TU Twente
# 93                      Kildare         Ireland      Estimating  TU Twente
# 94                           قم            Iran      Estimating  TU Twente
# 95                    Stevenage  United Kingdom      Estimating  TU Twente
# 96                   Grangettes     Switzerland      Estimating  TU Twente
# 97                Santa Clarita   United States      Estimating  TU Twente
# 98                         Birr         Ireland      Estimating  TU Twente
# 99                 Mountmellick         Ireland      Estimating  TU Twente
# 100                   Whangarei     New Zealand      Estimating  TU Twente
#
# [100 rows x 6 columns]

# %%
pd.read_sql_table('universities', engine, index_col='id')
# Out:
#          name      email_address
# id
# 1    TU Delft   TU_delft@bla.com
# 2   TU Twente  TU_Twente@bla.com

# %%
pd.read_sql_table('departments', engine, index_col='id')
# Out:
#           name       email_address
# id
# 1           IT         bla@bla.com
# 2   Estimating  Estimating@bla.com
