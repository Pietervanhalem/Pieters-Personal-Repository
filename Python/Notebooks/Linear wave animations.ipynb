# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib notebook
from matplotlib.patches import Circle

# %%
x0 = 20
x1 = 10
y0 = 0
y1 = -5
y2 = -10
y3 = -15
y4 = -20


a = 3
d = 20
k = 0.1141
w = 1.05

xl = np.arange(0,56,1)

Aa = a * (np.cosh(k*(d + y0)))/(np.sinh(k*d))
Ba = a * (np.sinh(k*(d + y0)))/(np.sinh(k*d))

Ab = a * (np.cosh(k*(d + y1)))/(np.sinh(k*d))
Bb = a * (np.sinh(k*(d + y1)))/(np.sinh(k*d))

Ac = a * (np.cosh(k*(d + y2)))/(np.sinh(k*d))
Bc = a * (np.sinh(k*(d + y2)))/(np.sinh(k*d))

Ad = a * (np.cosh(k*(d + y3)))/(np.sinh(k*d))
Bd = a * (np.sinh(k*(d + y3)))/(np.sinh(k*d))

Ae = a * (np.cosh(k*(d + y4)))/(np.sinh(k*d))
Be = a * (np.sinh(k*(d + y4)))/(np.sinh(k*d))

inte =1000
print(Aa)
# Out:
# 3.06318012121

# %%
def update_circle(i):
    t = i*inte/1000
    
    xa = x0 - Aa * np.cos(w*t - k * x0)
    ya = y0 + Ba * np.sin(w*t - k * x0)
    ca.center = (xa,ya)    
    xb = x0 - Ab * np.cos(w*t - k * x0)
    yb = y1 + Bb * np.sin(w*t - k * x0)
    cb.center = (xb,yb)
    xc = x0 - Ac * np.cos(w*t - k * x0)
    yc = y2 + Bc * np.sin(w*t - k * x0)
    cc.center = (xc,yc)
    xd = x0 - Ad * np.cos(w*t - k * x0)
    yd = y3 + Bd * np.sin(w*t - k * x0)
    cd.center = (xd,yd)
    xe = x0 - Ae * np.cos(w*t - k * x0)
    ye = y4 + Be * np.sin(w*t - k * x0)
    ce.center = (xe,ye)
    
    xa = x1 - Aa * np.cos(w*t - k * x1)
    ya = y0 + Ba * np.sin(w*t - k * x1)
    caa.center = (xa,ya)    
    xb = x1 - Ab * np.cos(w*t - k * x1)
    yb = y1 + Bb * np.sin(w*t - k * x1)
    cba.center = (xb,yb)
    xc = x1 - Ac * np.cos(w*t - k * x1)
    yc = y2 + Bc * np.sin(w*t - k * x1)
    cca.center = (xc,yc)
    xd = x1 - Ad * np.cos(w*t - k * x1)
    yd = y3 + Bd * np.sin(w*t - k * x1)
    cda.center = (xd,yd)
    xe = x1 - Ae * np.cos(w*t - k * x1)
    ye = y4 + Be * np.sin(w*t - k * x1)
    cea.center = (xe,ye)
    
    yl = a * np.sin(w*t - k* xl)
    line.set_data([xl], [yl])
    
    plt.title(t)
    
    uxa = w * Aa * np.cos(w*t - k * x0)+20
    uya = w * Ba * np.sin(w*t - k * x0)
    linea.set_data([20,uxa], [0,uya])
    uxb = w * Ab * np.cos(w*t - k * x0)+20
    uyb = w * Bb * np.sin(w*t - k * x0)-5
    lineb.set_data([20,uxb], [-5,uyb])
    uxc = w * Ac * np.cos(w*t - k * x0)+20
    uyc = w * Bc * np.sin(w*t - k * x0)-10
    linec.set_data([20,uxc], [-10,uyc])
    uxd = w * Ad * np.cos(w*t - k * x0)+20
    uyd = w * Bd * np.sin(w*t - k * x0)-15
    lined.set_data([20,uxd], [-15,uyd])
    uxe = w * Ae * np.cos(w*t - k * x0)+20
    uye = w * Be * np.sin(w*t - k * x0)-20
    linee.set_data([20,uxe], [-20,uye])
    
    uxaa = w * Aa * np.cos(w*t - k * x1)+10
    uyaa = w * Ba * np.sin(w*t - k * x1)
    lineaa.set_data([10,uxaa], [0,uyaa])
    uxba = w * Ab * np.cos(w*t - k * x1)+10
    uyba = w * Bb * np.sin(w*t - k * x1)-5
    lineba.set_data([10,uxba], [-5,uyba])
    uxca = w * Ac * np.cos(w*t - k * x1)+10
    uyca = w * Bc * np.sin(w*t - k * x1)-10
    lineca.set_data([10,uxca], [-10,uyca])
    uxda = w * Ad * np.cos(w*t - k * x1)+10
    uyda = w * Bd * np.sin(w*t - k * x1)-15
    lineda.set_data([10,uxda], [-15,uyda])
    uxea = w * Ae * np.cos(w*t - k * x1)+10
    uyea = w * Be * np.sin(w*t - k * x1)-20
    lineea.set_data([10,uxea], [-20,uyea])
    
    return 

fig = plt.figure(figsize=(10,3))
ax = plt.subplot(121, aspect = 'equal', xlim= (0, 55), ylim =(-20,5))

ca = Circle((-10,20), radius = 0.5, color='red')
ax.add_patch(ca)
cb = Circle((-10,20), radius = 0.5, color='black')
ax.add_patch(cb)
cc = Circle((-10,20), radius = 0.5, color='blue')
ax.add_patch(cc)
cd = Circle((-10,20), radius = 0.5, color='green')
ax.add_patch(cd)
ce = Circle((-10,20), radius = 0.5, color='Yellow')
ax.add_patch(ce)

caa = Circle((-10,20), radius = 0.5, color='red')
ax.add_patch(caa)
cba = Circle((-10,20), radius = 0.5, color='black')
ax.add_patch(cba)
cca = Circle((-10,20), radius = 0.5, color='blue')
ax.add_patch(cca)
cda = Circle((-10,20), radius = 0.5, color='green')
ax.add_patch(cda)
cea = Circle((-10,20), radius = 0.5, color='Yellow')
ax.add_patch(cea)

line, = plt.plot([], [], 'b')

ax = plt.subplot(122, aspect='equal', xlim=(0, 56), ylim=(-21, 5))
linea, = plt.plot([], [], 'r')
lineb, = plt.plot([], [], 'k')
linec, = plt.plot([], [], 'b')
lined, = plt.plot([], [], 'g')
linee, = plt.plot([], [], 'y')

lineaa, = plt.plot([], [], 'r')
lineba, = plt.plot([], [], 'k')
lineca, = plt.plot([], [], 'b')
lineda, = plt.plot([], [], 'g')
lineea, = plt.plot([], [], 'y')
animation.FuncAnimation(fig, update_circle, interval=inte)
# Out:
# <img src="data:image/png;base64,..." width="999.9333333333334">
